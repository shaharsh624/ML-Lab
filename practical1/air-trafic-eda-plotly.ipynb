# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

# %%
df_Departures =pd.read_csv("data/International_Report_Departures.csv")
df_Passengers =pd.read_csv("data/International_Report_Passengers.csv")

# %%
df_Departures
# Out:
#           data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id  \
# 0       05/01/2006  2006      5       12016     GUM        5      13162
# 1       05/01/2003  2003      5       10299     ANC        1      13856
# 2       03/01/2007  2007      3       10721     BOS       13      12651
# 3       12/01/2004  2004     12       11259     DAL       74      16271
# 4       05/01/2009  2009      5       13303     MIA       33      11075
# ...            ...   ...    ...         ...     ...      ...        ...
# 930803  07/01/2000  2000      7       13303     MIA       33      13605
# 930804  04/01/2019  2019      4       13303     MIA       33      14286
# 930805  08/01/2000  2000      8       13303     MIA       33      13605
# 930806  09/01/2004  2004      9       12266     IAH       74      15632
# 930807  05/01/1996  1996      5       12478     JFK       22      14210
#
#        fg_apt  fg_wac  airlineid carrier  carriergroup        type  Scheduled  \
# ...

# %%
df_Passengers
# Out:
#           data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id  \
# 0       05/01/2014  2014      5       14492     RDU       36      11032
# 1       06/01/2007  2007      6       13204     MCO       33      16085
# 2       12/01/2005  2005     12       11433     DTW       43      10411
# 3       04/01/2003  2003      4       13487     MSP       63      16304
# 4       12/01/2005  2005     12       12016     GUM        5      11138
# ...            ...   ...    ...         ...     ...      ...        ...
# 680980  10/01/2015  2015     10       12478     JFK       22      12972
# 680981  09/01/2014  2014      9       12478     JFK       22      12972
# 680982  10/01/2014  2014     10       12478     JFK       22      12972
# 680983  08/01/2014  2014      8       12478     JFK       22      12972
# 680984  03/01/1990  1990      3       12478     JFK       22      12972
#
#        fg_apt  fg_wac  airlineid carrier  carriergroup        type  Scheduled  \
# ...

# %% [markdown]
# ### check null values

# %%
df_Departures.isna().sum()
# Out:
# data_dte           0
# Year               0
# Month              0
# usg_apt_id         0
# usg_apt            0
# usg_wac            0
# fg_apt_id          0
# fg_apt             0
# fg_wac             0
# airlineid          0
# carrier         3055
# carriergroup       0
# type               0
# Scheduled          0
# Charter            0
# Total              0
# dtype: int64

# %%
df_Departures=df_Departures.dropna()

# %%
df_Departures.isna().sum()
# Out:
# data_dte        0
# Year            0
# Month           0
# usg_apt_id      0
# usg_apt         0
# usg_wac         0
# fg_apt_id       0
# fg_apt          0
# fg_wac          0
# airlineid       0
# carrier         0
# carriergroup    0
# type            0
# Scheduled       0
# Charter         0
# Total           0
# dtype: int64

# %%
df_Passengers.isna().sum()
# Out:
# data_dte           0
# Year               0
# Month              0
# usg_apt_id         0
# usg_apt            0
# usg_wac            0
# fg_apt_id          0
# fg_apt             0
# fg_wac             0
# airlineid          0
# carrier         2797
# carriergroup       0
# type               0
# Scheduled          0
# Charter            0
# Total              0
# dtype: int64

# %%
df_Passengers=df_Passengers.dropna()

# %%
df_Passengers.isna().sum()
# Out:
# data_dte        0
# Year            0
# Month           0
# usg_apt_id      0
# usg_apt         0
# usg_wac         0
# fg_apt_id       0
# fg_apt          0
# fg_wac          0
# airlineid       0
# carrier         0
# carriergroup    0
# type            0
# Scheduled       0
# Charter         0
# Total           0
# dtype: int64

# %% [markdown]
# ### Check duplicates

# %%
df_Departures.duplicated().value_counts()
# Out:
# False    927753
# Name: count, dtype: int64

# %%
df_Passengers.duplicated().sum()
# Out:
# 0

# %%
df_Departures.describe()
# Out:
#                 Year          Month     usg_apt_id        usg_wac  \
# count  927753.000000  927753.000000  927753.000000  927753.000000
# mean     2006.039484       6.414815   12807.082771      42.602816
# std         8.559148       3.471259    2718.960303      27.554075
# min      1990.000000       1.000000   10010.000000       1.000000
# 25%      1999.000000       3.000000   11618.000000      22.000000
# 50%      2007.000000       6.000000   12892.000000      33.000000
# 75%      2014.000000       9.000000   13487.000000      72.000000
# max      2020.000000      12.000000   99999.000000      93.000000
#
#            fg_apt_id         fg_wac      airlineid   carriergroup  \
# count  927753.000000  927753.000000  927753.000000  927753.000000
# mean    13485.187354     467.448589   20056.041096       0.598042
# std      1933.133521     288.183269     479.420013       0.490294
# min     10119.000000     106.000000   19386.000000       0.000000
# ...

# %%
df_Passengers.describe()
# Out:
#                 Year          Month     usg_apt_id        usg_wac  \
# count  678188.000000  678188.000000  678188.000000  678188.000000
# mean     2006.166665       6.366450   12775.599487      44.521627
# std         8.715608       3.466918    2513.630997      28.079747
# min      1990.000000       1.000000   10010.000000       1.000000
# 25%      1999.000000       3.000000   11618.000000      22.000000
# 50%      2007.000000       6.000000   12889.000000      33.000000
# 75%      2014.000000       9.000000   13796.000000      74.000000
# max      2020.000000      12.000000   99999.000000      93.000000
#
#            fg_apt_id         fg_wac      airlineid   carriergroup  \
# count  678188.000000  678188.000000  678188.000000  678188.000000
# mean    13494.106069     468.866780   20030.031640       0.560427
# std      1956.742129     293.048994     510.728331       0.496335
# min     10125.000000     106.000000   19386.000000       0.000000
# ...

# %% [markdown]
# ## Concatenate both dataset

# %%
full_data=pd.concat([df_Departures,df_Passengers],axis=0)
full_data
# Out:
#           data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id  \
# 0       05/01/2006  2006      5       12016     GUM        5      13162
# 1       05/01/2003  2003      5       10299     ANC        1      13856
# 2       03/01/2007  2007      3       10721     BOS       13      12651
# 3       12/01/2004  2004     12       11259     DAL       74      16271
# 4       05/01/2009  2009      5       13303     MIA       33      11075
# ...            ...   ...    ...         ...     ...      ...        ...
# 680980  10/01/2015  2015     10       12478     JFK       22      12972
# 680981  09/01/2014  2014      9       12478     JFK       22      12972
# 680982  10/01/2014  2014     10       12478     JFK       22      12972
# 680983  08/01/2014  2014      8       12478     JFK       22      12972
# 680984  03/01/1990  1990      3       12478     JFK       22      12972
#
#        fg_apt  fg_wac  airlineid carrier  carriergroup        type  Scheduled  \
# ...

# %%
full_data.tail(10)
# Out:
#           data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id  \
# 680975  07/01/2015  2015      7       12478     JFK       22      12972
# 680976  09/01/2013  2013      9       12478     JFK       22      12972
# 680977  05/01/2014  2014      5       12478     JFK       22      12972
# 680978  06/01/2015  2015      6       12478     JFK       22      12972
# 680979  06/01/2014  2014      6       12478     JFK       22      12972
# 680980  10/01/2015  2015     10       12478     JFK       22      12972
# 680981  09/01/2014  2014      9       12478     JFK       22      12972
# 680982  10/01/2014  2014     10       12478     JFK       22      12972
# 680983  08/01/2014  2014      8       12478     JFK       22      12972
# 680984  03/01/1990  1990      3       12478     JFK       22      12972
#
#        fg_apt  fg_wac  airlineid carrier  carriergroup        type  Scheduled  \
# 680975    LHR     493      19540      BA             0  Passengers     126916
# ...

# %%
# full_data.to_csv('data/data.csv', index=False)

# %%
fig = px.histogram(full_data, x='type', color_discrete_sequence=['deepskyblue'])

fig.update_layout(
    title='Distribution Of Type',
    title_font_size=20,
    title_font_color='black',
    xaxis_title='Type',
    yaxis_title='Count',
    xaxis_tickangle=-60,
    xaxis_showgrid=True,
    yaxis_showgrid=True
)

fig.show()

# %%
fig = px.histogram(full_data, x='carriergroup', color_discrete_sequence=['orange'])
fig.update_layout(
    title='Distribution Of CarrierGroup',
    title_font_size=20,
    xaxis_title='CarrierGroup',
    yaxis_title='Count',
    xaxis_tickangle=-45,
    xaxis_showgrid=True,
    yaxis_showgrid=True
)
fig.show()

# %%
fig = px.line(full_data, x='Year', y='Total', line_shape='linear', color_discrete_sequence=['deepskyblue'])
fig.update_layout(
    title='Total Flights by Year',
    title_font_size=20,
    xaxis_title='Year',
    yaxis_title='Total Flights',
    xaxis_tickangle=-45
)
fig.show()

# %%
fig = px.line(full_data, x='Year', y='Total', color='carriergroup', line_shape='linear', color_discrete_sequence=['green'])
fig.update_layout(
    title='Total Flights by Year',
    title_font_size=20,
    xaxis_title='Year',
    yaxis_title='Total Flights',
    xaxis_tickangle=-45,
    xaxis_showgrid=True,
    yaxis_showgrid=True
)
fig.show()

# %%
fig = px.bar(full_data, x='Year', y='Total', color='carriergroup', color_discrete_sequence=['lightblue'])
fig.update_layout(
    title='Total Flights by Year',
    title_font_size=20,
    xaxis_title='Year',
    yaxis_title='Total Flights',
    xaxis_tickangle=-45,
    xaxis_showgrid=True,
    yaxis_showgrid=True
)
fig.write_image("newplot.png")

# %%
fig = px.bar(full_data, x='Year', y='Total', color='type', color_discrete_sequence=['lightblue'])
fig.update_layout(
    title='Total Flights by Year',
    title_font_size=20,
    xaxis_title='Year',
    yaxis_title='Total Flights',
    xaxis_tickangle=-45,
    xaxis_showgrid=True,
    yaxis_showgrid=True
)
fig.write_image("newplot.png")

# %%
fig = px.line(full_data, x='Year', y='Scheduled', title='Total Flights per Year', labels={'Scheduled': 'Total Flights (in Million)'}, color_discrete_sequence=['#ff7f0e'])
fig.add_scatter(x=full_data['Year'], y=full_data['Charter'], mode='lines', name='Chartered Flights', line=dict(color='#1f77b4'))

fig.update_layout(
    title='Total Flights per Year',
    title_font_size=20,
    xaxis_title='Year',
    yaxis_title='Total Flights (in Million)',
    xaxis_tickangle=-45,
    xaxis_showgrid=True,
    yaxis_showgrid=True
)
fig.show()

# %%
# Define the subplot titles and colors
titles = ['BoxPlot For usg_wac', 'BoxPlot For fg_wac', 'BoxPlot For Charter', 'BoxPlot For Total']
colors = ['red', 'green', 'black', 'yellow']
columns = ['usg_wac', 'fg_wac', 'Charter', 'Total']

# Create a subplot grid
fig = make_subplots(rows=2, cols=2, subplot_titles=titles)

# Add box plots to the subplots
for i, column in enumerate(columns):
    row = i // 2 + 1
    col = i % 2 + 1
    fig.add_trace(
        go.Box(y=full_data[column], name=column, marker_color=colors[i]),
        row=row, col=col
    )

# Update layout
fig.update_layout(
    height=800, width=1000,
    title_text="BoxPlots for Different Categories",
    title_font_size=20,
    showlegend=False
)

fig.update_xaxes(title_text="Value", row=1, col=1)
fig.update_xaxes(title_text="Value", row=1, col=2)
fig.update_xaxes(title_text="Value", row=2, col=1)
fig.update_xaxes(title_text="Value", row=2, col=2)

fig.update_layout(
    title={'text': 'BoxPlot for Different Categories', 'x': 0.5, 'xanchor': 'center'},
    xaxis_title='Value',
    yaxis_title='Value'
)

fig.show()

# %%
# Compute the correlation matrix
numerical_data = full_data.select_dtypes(include=['number'])
correlation_matrix = numerical_data.corr()

# Create the heatmap
fig = go.Figure(data=go.Heatmap(
    z=correlation_matrix.values,
    x=correlation_matrix.columns,
    y=correlation_matrix.columns,
    colorscale='Blues',
    colorbar_title='Correlation',
    zmid=0
))

# Update layout
fig.update_layout(
    title='Correlation Matrix',
    xaxis_title='Variables',
    yaxis_title='Variables',
    xaxis_nticks=len(correlation_matrix.columns),
    yaxis_nticks=len(correlation_matrix.columns),
    xaxis_tickangle=-45
)

fig.show()
