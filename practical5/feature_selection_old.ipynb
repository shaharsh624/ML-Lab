# %% [markdown]
# ## Univariate feature selection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import HTML, display
from sklearn.feature_selection import SelectKBest, chi2

# %%
columns = ["Pregnancies", "GLucose", "BloodPressure", "Skin Thickness", "Insulin", "BMI", "DiabetesPedigreeFunction", "Age", "Outcome"]

# %%
df = pd.read_csv('./master_pima-indians-diabetes.csv', names=columns, header=None)

# %%
df
# Out:
#      Pregnancies  GLucose  BloodPressure  Skin Thickness  Insulin   BMI  \
# 0              6      148             72              35        0  33.6
# 1              1       85             66              29        0  26.6
# 2              8      183             64               0        0  23.3
# 3              1       89             66              23       94  28.1
# 4              0      137             40              35      168  43.1
# ..           ...      ...            ...             ...      ...   ...
# 763           10      101             76              48      180  32.9
# 764            2      122             70              27        0  36.8
# 765            5      121             72              23      112  26.2
# 766            1      126             60               0        0  30.1
# 767            1       93             70              31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
X = df.drop('Outcome', axis=1)

# %%
X
# Out:
#      Pregnancies  GLucose  BloodPressure  Skin Thickness  Insulin   BMI  \
# 0              6      148             72              35        0  33.6
# 1              1       85             66              29        0  26.6
# 2              8      183             64               0        0  23.3
# 3              1       89             66              23       94  28.1
# 4              0      137             40              35      168  43.1
# ..           ...      ...            ...             ...      ...   ...
# 763           10      101             76              48      180  32.9
# 764            2      122             70              27        0  36.8
# 765            5      121             72              23      112  26.2
# 766            1      126             60               0        0  30.1
# 767            1       93             70              31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# ...

# %%
y = df['Outcome']

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
feature_names = columns[:-1]

# %%
feature_names
# Out:
# ['Pregnancies',
#  'GLucose',
#  'BloodPressure',
#  'Skin Thickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
df1 = pd.DataFrame(X, columns=feature_names)
df1['target'] = y

# %%
df1
# Out:
#      Pregnancies  GLucose  BloodPressure  Skin Thickness  Insulin   BMI  \
# 0              6      148             72              35        0  33.6
# 1              1       85             66              29        0  26.6
# 2              8      183             64               0        0  23.3
# 3              1       89             66              23       94  28.1
# 4              0      137             40              35      168  43.1
# ..           ...      ...            ...             ...      ...   ...
# 763           10      101             76              48      180  32.9
# 764            2      122             70              27        0  36.8
# 765            5      121             72              23      112  26.2
# 766            1      126             60               0        0  30.1
# 767            1       93             70              31        0  30.4
#
#      DiabetesPedigreeFunction  Age  target
# 0                       0.627   50       1
# ...

# %%
k_best_features = 4
selector = SelectKBest(score_func=chi2, k=k_best_features)
X_new = selector.fit_transform(X, y)

# %%
selected_indices = selector.get_support(indices=True)
selected_feature_names = np.array(feature_names)[selected_indices]
print("Selected Features:", selected_feature_names)
# Out:
# Selected Features: ['GLucose' 'Insulin' 'BMI' 'Age']

# %%
total_features = X.shape[1]
selected_features = X_new.shape[1]
print("Total features in the original dataset:", total_features)
print("Total selected features after Univariate Feature Selection:", selected_features)
# Out:
# Total features in the original dataset: 8
# Total selected features after Univariate Feature Selection: 4

# %% [markdown]
# ## Recursive feature elimination (RFE)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.feature_selection import VarianceThreshold, RFE
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
n_features = 2
rfe = RFE(estimator=lr, n_features_to_select=n_features)
rfe.fit(X, y)
list_select_rfe = list(X.columns[rfe.support_])
list_select_rfe
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 4
#       2 n_features = 2
#       3 rfe = RFE(estimator=lr, n_features_to_select=n_features)
# ----> 4 rfe.fit(X, y)
#       5 list_select_rfe = list(X.columns[rfe.support_])
#       6 list_select_rfe
#
# File ~\miniconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\miniconda3\Lib\site-packages\sklearn\feature_selection\_rfe.py:268, in RFE.fit(self, X, y, **fit_params)
# ...
